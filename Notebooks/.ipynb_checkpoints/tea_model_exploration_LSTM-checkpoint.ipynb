# %% [markdown]
# # In this notebook, LSTM Univariate & Multivariate models will be explored

# %%
# %matplotlib inline

import os
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import signal
from scipy import stats

import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.tsa.statespace.sarimax import SARIMAX

import tensorflow as tf
keras = tf.keras
from tensorflow.keras.callbacks import CSVLogger, EarlyStopping

from sklearn.model_selection import train_test_split

# Always make it pretty.
plt.style.use('ggplot')

# We get some interger -> float typecast warning from sklean below, this keeps them out of our hair.
import warnings
warnings.filterwarnings('ignore')

import pickle
from datetime import datetime

# %% [markdown]
# ## LSTM

# %% [markdown]
# #### Reload the data

# %% [markdown]
# The plan:
#
# First run only price data to do a univariate LSTM ... DONE
# Check results for all data including 2020 ... Poor Results
#
# Check results for 2019 data only ... DONE, good results
# Compare one_step predictions with known data ... DONE dood results
#
# Then do multivariate with price, offer qty and sold qty, for 1 tea category
# Then add all categories

# %%
def get_timestamp():
    timestamp =   str(datetime.now().year) + '_'\
                + str(datetime.now().month).zfill(2) + '_'\
                + str(datetime.now().day).zfill(2) + '_'\
                + str(datetime.now().hour).zfill(2) + '_'\
                + str(datetime.now().minute).zfill(2) + '_'\
                + str(datetime.now().second).zfill(2)
    return ''

# %%
# load dataset
df_CHN_CTC_leaf = pd.read_csv('../Data/df_CHN_CTC_leaf.csv', header=0, index_col=0)
df_CHN_CTC_dust = pd.read_csv('../Data/df_CHN_CTC_dust.csv', header=0, index_col=0)
df_CHN_Ortho_leaf = pd.read_csv('../Data/df_CHN_Ortho_leaf.csv', header=0, index_col=0)
df_CHN_Ortho_dust = pd.read_csv('../Data/df_CHN_Ortho_dust.csv', header=0, index_col=0)

# %%
# chop out 2020 data
df_CHN_CTC_leaf = df_CHN_CTC_leaf[pd.to_datetime(df_CHN_CTC_leaf.index) < pd.to_datetime('2020-01-01')]
df_CHN_CTC_dust = df_CHN_CTC_dust[pd.to_datetime(df_CHN_CTC_dust.index) < pd.to_datetime('2020-01-01')]
df_CHN_Ortho_leaf = df_CHN_Ortho_leaf[pd.to_datetime(df_CHN_Ortho_leaf.index) < pd.to_datetime('2020-01-01')]
df_CHN_Ortho_dust = df_CHN_Ortho_dust[pd.to_datetime(df_CHN_Ortho_dust.index) < pd.to_datetime('2020-01-01')]

# %%
def plot_oqty_sqty_avgp(df, category, city):

    fig, axs = plt.subplots(3, figsize=(15, 10))

    axs[0].plot(pd.to_datetime(df.index), df[category + '_offer_qty'],'*-', c='r',
                label=category.upper() + ' Offer Qty')
    axs[0].set_title(category.upper() + ' Offer Qty - ' + city)
    axs[0].set_ylabel('Kgs')
    axs[0].legend(loc='best')
    axs[0].tick_params(rotation=75, axis='x')
                            
    axs[1].plot(pd.to_datetime(df.index), df[category + '_sold_qty'], '*-', c='g',
                label=category.upper() + ' Sold Qty')
    axs[1].set_title(category.upper() + ' Sold Qty - ' + city)
    axs[1].set_ylabel('Kgs')
    axs[1].legend(loc='best')
    axs[1].tick_params(rotation=75, axis='x')
                            
    axs[2].plot(pd.to_datetime(df.index), df[category + '_avg_price'],'*-', c='b',
                label=category.upper() + ' Avg Price')
    axs[2].set_title(category.upper() + ' Avg Price - ' + city)
    axs[2].set_ylabel('Rs. per Kg')
    axs[2].legend(loc='best')
    axs[2].tick_params(rotation=75, axis='x')


    fig.tight_layout()
    fig.savefig('../Images/' + category.upper() + '_' + city + '_oqty_sqty_avgp' + get_timestamp())

# %%
plot_oqty_sqty_avgp(df_CHN_CTC_leaf, 'ctc_leaf', 'Cochin')
plot_oqty_sqty_avgp(df_CHN_CTC_dust, 'ctc_dust', 'Cochin')
plot_oqty_sqty_avgp(df_CHN_Ortho_leaf, 'ortho_leaf', 'Cochin')
plot_oqty_sqty_avgp(df_CHN_Ortho_dust, 'ortho_dust', 'Cochin')

# %% [markdown]
# ## Univariate (Price only)

# %% [markdown]
# First we need to get the data into a format we can put into an RNN. Each training data point should consist of a sequence of consecutive values for our data (for input) and the next value of our data (for output).
#
# First, a function to consider every possible group of n_prev values followed by one value (for the output) along the time-series data.

# %%
# Set up the first price series
price_series = df_CHN_CTC_leaf['ctc_leaf_avg_price']
time_series = price_series.index #pd.to_datetime(df_CHN_CTC_leaf['week_ending'])
# price_series.index = time_series
time_series
# Out:
# Index(['14-Jan-12', '21-Jan-12', '28-Jan-12', '4-Feb-12', '11-Feb-12',
#        '18-Feb-12', '25-Feb-12', '3-Mar-12', '10-Mar-12', '17-Mar-12',
#        ...
#        '26-Oct-19', '2-Nov-19', '9-Nov-19', '16-Nov-19', '23-Nov-19',
#        '30-Nov-19', '7-Dec-19', '14-Dec-19', '21-Dec-19', '28-Dec-19'],
#       dtype='object', name='week_ending', length=412)

# %%
def windowize_data(data, n_prev):
    n_predictions = len(data) - n_prev
    y = data[n_prev:]
    # this might be too clever
    indices = np.arange(n_prev) + np.arange(n_predictions)[:, None]
    x = data[indices, None]
    return x, y

# %% [markdown]
# Then we'll write a function split the data into training and testing sets. Because it's time-series data we have to do that sequentially rather than shuffling it. They should be completely separate and not overlap, so the the training data isn't used for testing.

# %%
def split_and_windowize(data, n_prev, fraction_test=0.05):
    n_predictions = len(data) - 2*n_prev
    
    n_test  = int(fraction_test * n_predictions)
    n_train = n_predictions - n_test   
    
    x_train, y_train = windowize_data(data[:n_train], n_prev)
    x_test, y_test = windowize_data(data[n_train:], n_prev)
    return x_train, x_test, y_train, y_test

# %%
df_CHN_CTC_leaf
# Out:
#              year  serial_no  ctc_leaf_offer_qty  ctc_leaf_sold_qty  \
# week_ending
# 14-Jan-12    2012          2             83325.0            77015.0
# 21-Jan-12    2012          3             71897.0            68187.0
# 28-Jan-12    2012          4             91279.0            78695.0
# 4-Feb-12     2012          5             83746.0            71188.0
# 11-Feb-12    2012          6             89650.0            85480.0
# ...           ...        ...                 ...                ...
# 30-Nov-19    2019         48             36457.0            17801.0
# 7-Dec-19     2019         49             35657.0            12185.0
# 14-Dec-19    2019         50             28768.0            13576.0
# 21-Dec-19    2019         51             34565.0            19960.0
# 28-Dec-19    2019         52             39329.0            21016.0
#
#              ctc_leaf_avg_price
# week_ending
# 14-Jan-12                 68.03
# 21-Jan-12                 70.11
# 28-Jan-12                 70.73
# 4-Feb-12                  70.63
# 11-Feb-12                 69.23
# ...                         ...
# 30-Nov-19                 86.08
# 7-Dec-19                  84.15
# 14-Dec-19                 85.86
# 21-Dec-19                 86.39
# 28-Dec-19                 86.89
#
# [412 rows x 5 columns]

# %%
n_prev = 10

x_train, x_test, y_train, y_test = split_and_windowize(price_series.values, n_prev)
x_train.shape, x_test.shape, y_train.shape, y_test.shape

# ((363, 10, 3), (29, 10, 3), (363, 3), (29, 3))
# Out:
# ((363, 10, 1), (29, 10, 1), (363,), (29,))

# %% [markdown]
# The "vanishing gradients problem" of traditional RNNs,  where the effect of the input at the beginning exponentially shrinks with the depth of the network, makes it very hard to remember details from the signal from each successively earlier point.
#
# Long Short Term Memory (LSTM) networks do a better job of handling long-term dependencies. [http://colah.github.io/posts/2015-08-Understanding-LSTMs/]

# %%
# LSTM_price_model = keras.Sequential()

# LSTM_price_model.add(keras.layers.LSTM(52, input_shape=(n_prev, 1), return_sequences=True))

# LSTM_price_model.add(keras.layers.LSTM(52, return_sequences=False))

# LSTM_price_model.add(keras.layers.Dense(1, activation='relu')) # 'linear'

# LSTM_price_model.compile(optimizer='adam', loss='mse')

# %%
LSTM_price_model = keras.Sequential()

LSTM_price_model.add(keras.layers.LSTM(32, input_shape=(n_prev, 1), return_sequences=True))

LSTM_price_model.add(keras.layers.Dropout(0.1))

LSTM_price_model.add(keras.layers.LSTM(32, return_sequences=False))

LSTM_price_model.add(keras.layers.Dense(1, activation='relu')) # 'linear'

LSTM_price_model.compile(optimizer='adam', loss='mape')

# %%
LSTM_price_model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_8 (LSTM)                (None, 10, 32)            4352
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 10, 32)            0
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 12,705
# Trainable params: 12,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
LSTM_price_model_history = LSTM_price_model.fit(x_train, 
                                                y_train, 
                                                validation_data=(x_test, y_test), 
                                                batch_size=10, 
                                                epochs=500)
# Out:
# Epoch 1/500
# 37/37 [==============================] - 1s 20ms/step - loss: 97.5597 - val_loss: 95.1436
# Epoch 2/500
# 37/37 [==============================] - 0s 7ms/step - loss: 93.0648 - val_loss: 90.7699
# Epoch 3/500
# 37/37 [==============================] - 0s 6ms/step - loss: 89.4990 - val_loss: 88.1514
# Epoch 4/500
# 37/37 [==============================] - 0s 6ms/step - loss: 87.3646 - val_loss: 86.2779
# Epoch 5/500
# 37/37 [==============================] - 0s 6ms/step - loss: 85.5973 - val_loss: 84.5499
# Epoch 6/500
# 37/37 [==============================] - 0s 6ms/step - loss: 83.9229 - val_loss: 82.8915
# Epoch 7/500
# 37/37 [==============================] - 0s 6ms/step - loss: 82.3015 - val_loss: 81.2831
# Epoch 8/500
# 37/37 [==============================] - 0s 6ms/step - loss: 80.7207 - val_loss: 79.6941
# Epoch 9/500
# 37/37 [==============================] - 0s 6ms/step - loss: 79.1590 - val_loss: 78.1217
# Epoch 10/500
# 37/37 [==============================] - 0s 6ms/step - loss: 77.6151 - val_loss: 76.5702
# Epoch 11/500
# 37/37 [==============================] - 0s 6ms/step - loss: 76.0849 - val_loss: 75.0302
# Epoch 12/500
500
# 37/37 [==============================] - 0s 6ms/step - loss: 11.0595 - val_loss: 3.0003
# Epoch 78/500
# 37/37 [==============================] - 0s 6ms/step - loss: 11.0470 - val_loss: 2.9816
# Epoch 79/500
# 37/37 [==============================] - 0s 6ms/step - loss: 11.0387 - val_loss: 2.9584
# Epoch 80/500
# 37/37 [==============================] - 0s 6ms/step - loss: 11.0275 - val_loss: 2.9489
# Epoch 81/500
# 37/37 [==============================] - 0s 6ms/step - loss: 11.0212 - val_loss: 2.9483
# Epoch 82/500
# 37/37 [==============================] - 0s 6ms/step - loss: 11.0121 - val_loss: 2.9477
# Epoch 83/500
# 37/37 [==============================] - 0s 6ms/step - loss: 11.0082 - val_loss: 2.9466
# Epoch 84/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9956 - val_loss: 2.9461
# Epoch 85/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9929 - val_loss: 2.9459
# Epoch 86/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9851 - val_loss: 2.9451
# Epoch 87/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9816 - val_loss: 2.9445
# Epoch 88/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9761 - val_loss: 2.9438
# Epoch 89/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9763 - val_loss: 2.9438
# Epoch 90/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9737 - val_loss: 2.9561
# Epoch 91/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9672 - val_loss: 2.9624
# Epoch 92/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9659 - val_loss: 2.9640
# Epoch 93/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9609 - val_loss: 2.9682
# Epoch 94/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9559 - val_loss: 2.9743
# Epoch 95/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9526 - val_loss: 2.9907
# Epoch 96/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9553 - val_loss: 3.0060
# Epoch 97/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9539 - val_loss: 2.9927
# Epoch 98/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9517 - val_loss: 2.9923
# Epoch 99/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9541 - val_loss: 3.0127
# Epoch 100/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9528 - val_loss: 3.0176
# Epoch 101/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9509 - val_loss: 3.0191
# Epoch 102/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9533 - val_loss: 3.0326
# Epoch 103/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9516 - val_loss: 3.0133
# Epoch 104/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9525 - val_loss: 3.0307
# Epoch 105/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9511 - val_loss: 3.0135
# Epoch 106/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9513 - val_loss: 3.0067
# Epoch 107/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9519 - val_loss: 3.0218
# Epoch 108/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9506 - val_loss: 3.0276
# Epoch 109/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9503 - val_loss: 3.0134
# Epoch 110/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9509 - val_loss: 3.0214
# Epoch 111/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9531 - val_loss: 3.0341
# Epoch 112/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9504 - val_loss: 3.0229
# Epoch 113/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9521 - val_loss: 3.0267
# Epoch 114/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9501 - val_loss: 3.0294
# Epoch 115/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9532 - val_loss: 3.0298
# Epoch 116/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9515 - val_loss: 3.0279
# Epoch 117/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9505 - val_loss: 3.0355
# Epoch 118/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9514 - val_loss: 3.0488
# Epoch 119/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9526 - val_loss: 3.0360
# Epoch 120/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9519 - val_loss: 3.0461
# Epoch 121/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9528 - val_loss: 3.0443
# Epoch 122/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9513 - val_loss: 3.0517
# Epoch 123/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9545 - val_loss: 3.0352
# Epoch 124/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9508 - val_loss: 3.0366
# Epoch 125/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9514 - val_loss: 3.0289
# Epoch 126/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9513 - val_loss: 3.0288
# Epoch 127/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9521 - val_loss: 3.0152
# Epoch 128/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9507 - val_loss: 3.0388
# Epoch 129/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9522 - val_loss: 3.0428
# Epoch 130/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9536 - val_loss: 3.0398
# Epoch 131/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9496 - val_loss: 2.9673
# Epoch 132/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.8829 - val_loss: 2.9862
# Epoch 133/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10.9091 - val_loss: 3.1193
# Epoch 134/500
# 37/37 [==============================] - 0s 6ms/step - loss: 10
500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5511 - val_loss: 2.5940
# Epoch 189/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.7409 - val_loss: 2.6931
# Epoch 190/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.8135 - val_loss: 2.3212
# Epoch 191/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.6632 - val_loss: 2.1764
# Epoch 192/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.8011 - val_loss: 3.5404
# Epoch 193/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.8981 - val_loss: 2.4765
# Epoch 194/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.7512 - val_loss: 2.1670
# Epoch 195/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5723 - val_loss: 2.2267
# Epoch 196/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.6211 - val_loss: 3.9057
# Epoch 197/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.8599 - val_loss: 2.7652
# Epoch 198/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.6159 - val_loss: 3.5857
# Epoch 199/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.7538 - val_loss: 5.4974
# Epoch 200/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.6511 - val_loss: 2.6273
# Epoch 201/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.7624 - val_loss: 4.3866
# Epoch 202/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.7726 - val_loss: 3.9622
# Epoch 203/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.6591 - val_loss: 3.5800
# Epoch 204/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5557 - val_loss: 2.4189
# Epoch 205/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.8084 - val_loss: 2.3772
# Epoch 206/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.7941 - val_loss: 2.9337
# Epoch 207/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.6002 - val_loss: 2.2272
# Epoch 208/500
# 37/37 [==============================] - 0s 6ms/step - loss: 4.1172 - val_loss: 2.3382
# Epoch 209/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.6642 - val_loss: 2.6159
# Epoch 210/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5686 - val_loss: 2.9733
# Epoch 211/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.6822 - val_loss: 2.1728
# Epoch 212/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.7187 - val_loss: 2.3885
# Epoch 213/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5683 - val_loss: 2.4541
# Epoch 214/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3596 - val_loss: 1.9625
# Epoch 215/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5184 - val_loss: 4.8823
# Epoch 216/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4065 - val_loss: 2.1278
# Epoch 217/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5867 - val_loss: 2.0929
# Epoch 218/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.6581 - val_loss: 2.1707
# Epoch 219/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5619 - val_loss: 2.0287
# Epoch 220/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3267 - val_loss: 2.0001
# Epoch 221/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5009 - val_loss: 2.5572
# Epoch 222/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5595 - val_loss: 2.3575
# Epoch 223/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4692 - val_loss: 2.5341
# Epoch 224/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5055 - val_loss: 3.1850
# Epoch 225/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4180 - val_loss: 2.8766
# Epoch 226/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5942 - val_loss: 2.8933
# Epoch 227/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4912 - val_loss: 2.2155
# Epoch 228/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4961 - val_loss: 3.4762
# Epoch 229/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.6478 - val_loss: 2.0087
# Epoch 230/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3527 - val_loss: 1.8745
# Epoch 231/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4933 - val_loss: 2.1045
# Epoch 232/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5302 - val_loss: 2.0173
# Epoch 233/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.6428 - val_loss: 2.6676
# Epoch 234/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4146 - val_loss: 2.2596
# Epoch 235/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4453 - val_loss: 1.8302
# Epoch 236/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5138 - val_loss: 2.0853
# Epoch 237/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4989 - val_loss: 1.9786
# Epoch 238/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4345 - val_loss: 2.2259
# Epoch 239/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4932 - val_loss: 2.0623
# Epoch 240/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5843 - val_loss: 2.0156
# Epoch 241/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4655 - val_loss: 2.8679
# Epoch 242/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3749 - val_loss: 2.7652
# Epoch 243/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5926 - val_loss: 1.8451
# Epoch 244/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5236 - val_loss: 2.2019
# Epoch 245/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3781 - val_loss: 1.8834
# Epoch 246/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5471 - val_loss: 2.0634
# Epoch 247/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5823 - val_loss: 1.9392
# Epoch 248/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3844 - val_loss: 2.1734
# Epoch 249/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5095 - val_loss: 1.9276
# Epoch 250/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3244 - val_loss: 2.4619
# Epoch 251/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4847 - val_loss: 1.9358
# Epoch 252/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3664 - val_loss: 1.9134
# Epoch 253/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3452 - val_loss: 2.4194
# Epoch 254/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3663 - val_loss: 3.3499
# Epoch 255/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4686 - val_loss: 1.9598
# Epoch 256/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3087 - val_loss: 2.0555
# Epoch 257/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3426 - val_loss: 2.1413
# Epoch 258/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4246 - val_loss: 2.1243
# Epoch 259/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4268 - val_loss: 2.3852
# Epoch 260/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2993 - val_loss: 2.7719
# Epoch 261/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3506 - val_loss: 2.7264
# Epoch 262/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3457 - val_loss: 2.0088
# Epoch 263/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2515 - val_loss: 2.1188
# Epoch 264/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4541 - val_loss: 2.3060
# Epoch 265/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.6473 - val_loss: 2.1445
# Epoch 266/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3094 - val_loss: 3.7810
# Epoch 267/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4099 - val_loss: 2.1341
# Epoch 268/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3044 - val_loss: 1.9630
# Epoch 269/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4658 - val_loss: 1.7819
# Epoch 270/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3971 - val_loss: 1.8388
# Epoch 271/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3721 - val_loss: 1.8522
# Epoch 272/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3409 - val_loss: 1.9348
# Epoch 273/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4103 - val_loss: 1.9669
# Epoch 274/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3828 - val_loss: 2.0274
# Epoch 275/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3676 - val_loss: 2.0378
# Epoch 276/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4932 - val_loss: 1.9816
# Epoch 277/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3357 - val_loss: 1.9230
# Epoch 278/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2993 - val_loss: 2.1956
# Epoch 279/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3383 - val_loss: 2.7293
# Epoch 280/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4488 - val_loss: 1.9960
# Epoch 281/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4617 - val_loss: 1.8494
# Epoch 282/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1685 - val_loss: 2.3900
# Epoch 283/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2682 - val_loss: 1.9291
# Epoch 284/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3121 - val_loss: 2.6572
# Epoch 285/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3340 - val_loss: 2.3746
# Epoch 286/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2368 - val_loss: 1.8361
# Epoch 287/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1688 - val_loss: 1.9789
# Epoch 288/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1306 - val_loss: 1.9201
# Epoch 289/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2663 - val_loss: 2.0555
# Epoch 290/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4666 - val_loss: 2.3550
# Epoch 291/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2855 - val_loss: 3.2000
# Epoch 292/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3488 - val_loss: 2.0597
# Epoch 293/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2510 - val_loss: 2.4382
# Epoch 294/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3212 - val_loss: 1.8254
# Epoch 295/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2958 - val_loss: 2.1039
# Epoch 296/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2388 - val_loss: 2.6037
# Epoch 297/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3664 - val_loss: 3.1956
# Epoch 298/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3790 - val_loss: 1.9756
# Epoch 299/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3154 - val_loss: 2.6342
# Epoch 300/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1736 - val_loss: 2.5007
# Epoch 301/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1430 - val_loss: 2.0295
# Epoch 302/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3301 - val_loss: 2.7168
# Epoch 303/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5970 - val_loss: 3.1899
# Epoch 304/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5004 - val_loss: 1.8544
# Epoch 305/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5861 - val_loss: 2.0034
# Epoch 306/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2806 - val_loss: 2.4092
# Epoch 307/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2839 - val_loss: 1.8134
# Epoch 308/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5047 - val_loss: 2.0515
# Epoch 309/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2364 - val_loss: 2.1290
# Epoch 310/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2751 - val_loss: 1.8805
# Epoch 311/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1818 - val_loss: 2.2437
# Epoch 312/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1553 - val_loss: 2.6963
# Epoch 313/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4535 - val_loss: 1.9882
# Epoch 314/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3215 - val_loss: 2.0134
# Epoch 315/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1682 - val_loss: 2.2330
# Epoch 316/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3719 - val_loss: 2.1240
# Epoch 317/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2059 - val_loss: 1.9352
# Epoch 318/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2399 - val_loss: 1.9364
# Epoch 319/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2148 - val_loss: 2.4279
# Epoch 320/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2509 - val_loss: 2.2208
# Epoch 321/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2664 - val_loss: 2.0778
# Epoch 322/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1623 - val_loss: 3.0212
# Epoch 323/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3650 - val_loss: 2.1557
# Epoch 324/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3533 - val_loss: 2.1794
# Epoch 325/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2419 - val_loss: 2.8610
# Epoch 326/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3707 - val_loss: 3.4042
# Epoch 327/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3302 - val_loss: 3.1643
# Epoch 328/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2903 - val_loss: 1.9145
# Epoch 329/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1655 - val_loss: 1.8754
# Epoch 330/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0738 - val_loss: 2.5585
# Epoch 331/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1705 - val_loss: 3.0705
# Epoch 332/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2016 - val_loss: 2.9512
# Epoch 333/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1553 - val_loss: 2.7722
# Epoch 334/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3243 - val_loss: 3.5391
# Epoch 335/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2969 - val_loss: 2.0383
# Epoch 336/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3357 - val_loss: 2.5054
# Epoch 337/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2163 - val_loss: 2.0293
# Epoch 338/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2830 - val_loss: 2.1454
# Epoch 339/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4064 - val_loss: 2.5593
# Epoch 340/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0956 - val_loss: 1.9741
# Epoch 341/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2863 - val_loss: 1.9669
# Epoch 342/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2342 - val_loss: 2.8201
# Epoch 343/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3003 - val_loss: 2.3762
# Epoch 344/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2209 - val_loss: 2.0443
# Epoch 345/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4255 - val_loss: 2.0152
# Epoch 346/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4200 - val_loss: 2.0843
# Epoch 347/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2358 - val_loss: 3.0284
# Epoch 348/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1761 - val_loss: 2.0769
# Epoch 349/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2161 - val_loss: 1.8647
# Epoch 350/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1000 - val_loss: 2.0789
# Epoch 351/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0229 - val_loss: 2.0857
# Epoch 352/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2796 - val_loss: 2.4296
# Epoch 353/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0835 - val_loss: 1.8162
# Epoch 354/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1707 - val_loss: 1.9821
# Epoch 355/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1032 - val_loss: 2.2605
# Epoch 356/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1916 - val_loss: 1.9011
# Epoch 357/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1533 - val_loss: 1.9830
# Epoch 358/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2376 - val_loss: 1.9701
# Epoch 359/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1281 - val_loss: 2.1598
# Epoch 360/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3024 - val_loss: 2.3329
# Epoch 361/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2421 - val_loss: 2.0281
# Epoch 362/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2036 - val_loss: 2.0702
# Epoch 363/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1005 - val_loss: 2.2590
# Epoch 364/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1578 - val_loss: 3.4487
# Epoch 365/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2020 - val_loss: 1.9190
# Epoch 366/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1557 - val_loss: 1.9884
# Epoch 367/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0560 - val_loss: 3.7779
# Epoch 368/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5924 - val_loss: 1.8991
# Epoch 369/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0940 - val_loss: 2.4231
# Epoch 370/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0536 - val_loss: 2.5521
# Epoch 371/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1482 - val_loss: 3.4014
# Epoch 372/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2936 - val_loss: 2.8386
# Epoch 373/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2200 - val_loss: 2.0151
# Epoch 374/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1966 - val_loss: 2.1662
# Epoch 375/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0931 - val_loss: 2.1065
# Epoch 376/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3320 - val_loss: 2.0355
# Epoch 377/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1841 - val_loss: 2.0951
# Epoch 378/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2696 - val_loss: 1.9939
# Epoch 379/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1583 - val_loss: 2.5722
# Epoch 380/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1809 - val_loss: 1.9324
# Epoch 381/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1355 - val_loss: 2.4258
# Epoch 382/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1739 - val_loss: 1.9612
# Epoch 383/500
# 37/37 [==============================] - 0s 6ms/step - loss: 2.9814 - val_loss: 2.8635
# Epoch 384/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2689 - val_loss: 3.1290
# Epoch 385/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2092 - val_loss: 2.2931
# Epoch 386/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1915 - val_loss: 1.9449
# Epoch 387/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0414 - val_loss: 1.8659
# Epoch 388/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1842 - val_loss: 1.8458
# Epoch 389/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3225 - val_loss: 1.8212
# Epoch 390/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.4767 - val_loss: 2.9487
# Epoch 391/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0670 - val_loss: 1.8260
# Epoch 392/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1189 - val_loss: 2.4337
# Epoch 393/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0739 - val_loss: 1.9499
# Epoch 394/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2412 - val_loss: 2.8441
# Epoch 395/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1346 - val_loss: 2.5182
# Epoch 396/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1913 - val_loss: 1.9108
# Epoch 397/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2349 - val_loss: 1.7562
# Epoch 398/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1671 - val_loss: 1.8347
# Epoch 399/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1635 - val_loss: 2.3251
# Epoch 400/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1752 - val_loss: 1.9518
# Epoch 401/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2563 - val_loss: 2.0791
# Epoch 402/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1194 - val_loss: 3.0699
# Epoch 403/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1883 - val_loss: 3.1434
# Epoch 404/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1503 - val_loss: 1.9805
# Epoch 405/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0858 - val_loss: 1.8270
# Epoch 406/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1939 - val_loss: 2.5429
# Epoch 407/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0946 - val_loss: 1.9793
# Epoch 408/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1678 - val_loss: 2.1038
# Epoch 409/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1688 - val_loss: 2.3326
# Epoch 410/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2045 - val_loss: 2.2430
# Epoch 411/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0540 - val_loss: 1.7676
# Epoch 412/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1779 - val_loss: 1.8761
# Epoch 413/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1128 - val_loss: 2.8448
# Epoch 414/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0715 - val_loss: 2.4689
# Epoch 415/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1957 - val_loss: 1.8361
# Epoch 416/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0058 - val_loss: 1.8645
# Epoch 417/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0089 - val_loss: 2.0869
# Epoch 418/500
# 37/37 [==============================] - 0s 6ms/step - loss: 2.9702 - val_loss: 2.5842
# Epoch 419/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1293 - val_loss: 1.9172
# Epoch 420/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1054 - val_loss: 1.9123
# Epoch 421/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0821 - val_loss: 2.1827
# Epoch 422/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1098 - val_loss: 1.7640
# Epoch 423/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1658 - val_loss: 2.0702
# Epoch 424/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2330 - val_loss: 2.1540
# Epoch 425/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0361 - val_loss: 2.1641
# Epoch 426/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2046 - val_loss: 2.6330
# Epoch 427/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1335 - val_loss: 1.8927
# Epoch 428/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1140 - val_loss: 1.8121
# Epoch 429/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0807 - val_loss: 1.8336
# Epoch 430/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0709 - val_loss: 2.1720
# Epoch 431/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2202 - val_loss: 1.9760
# Epoch 432/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0363 - val_loss: 3.1373
# Epoch 433/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.5701 - val_loss: 1.8646
# Epoch 434/500
# 37/37 [==============================] - 0s 6ms/step - loss: 2.9971 - val_loss: 1.8091
# Epoch 435/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1077 - val_loss: 1.9235
# Epoch 436/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3427 - val_loss: 2.0425
# Epoch 437/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0251 - val_loss: 1.7335
# Epoch 438/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1217 - val_loss: 2.0504
# Epoch 439/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0737 - val_loss: 1.9530
# Epoch 440/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0492 - val_loss: 2.0169
# Epoch 441/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1171 - val_loss: 2.0531
# Epoch 442/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2708 - val_loss: 1.8881
# Epoch 443/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1057 - val_loss: 1.9532
# Epoch 444/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1472 - val_loss: 1.9132
# Epoch 445/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0861 - val_loss: 2.0182
# Epoch 446/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0357 - val_loss: 2.8038
# Epoch 447/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0974 - val_loss: 1.9954
# Epoch 448/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0828 - val_loss: 2.0240
# Epoch 449/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0318 - val_loss: 1.7672
# Epoch 450/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0585 - val_loss: 1.8338
# Epoch 451/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0901 - val_loss: 1.8700
# Epoch 452/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0709 - val_loss: 2.4440
# Epoch 453/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1707 - val_loss: 2.4275
# Epoch 454/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3287 - val_loss: 2.0184
# Epoch 455/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1065 - val_loss: 2.6364
# Epoch 456/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1982 - val_loss: 1.9549
# Epoch 457/500
# 37/37 [==============================] - 0s 6ms/step - loss: 2.9910 - val_loss: 2.0099
# Epoch 458/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0517 - val_loss: 1.9379
# Epoch 459/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1632 - val_loss: 2.0082
# Epoch 460/500
# 37/37 [==============================] - 0s 6ms/step - loss: 2.9991 - val_loss: 1.9882
# Epoch 461/500
# 37/37 [==============================] - 0s 6ms/step - loss: 2.9584 - val_loss: 2.1806
# Epoch 462/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0136 - val_loss: 2.0701
# Epoch 463/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2353 - val_loss: 2.6584
# Epoch 464/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0888 - val_loss: 1.8580
# Epoch 465/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2761 - val_loss: 2.2912
# Epoch 466/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0993 - val_loss: 2.8673
# Epoch 467/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1938 - val_loss: 1.9613
# Epoch 468/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1383 - val_loss: 2.1904
# Epoch 469/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0873 - val_loss: 2.0085
# Epoch 470/500
# 37/37 [==============================] - 0s 6ms/step - loss: 2.9947 - val_loss: 1.9312
# Epoch 471/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1273 - val_loss: 1.9448
# Epoch 472/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1082 - val_loss: 2.0167
# Epoch 473/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2060 - val_loss: 1.8129
# Epoch 474/500
# 37/37 [==============================] - 0s 6ms/step - loss: 2.9698 - val_loss: 1.7261
# Epoch 475/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0267 - val_loss: 2.0901
# Epoch 476/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1140 - val_loss: 1.8099
# Epoch 477/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0980 - val_loss: 1.7865
# Epoch 478/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0528 - val_loss: 1.9466
# Epoch 479/500
# 37/37 [==============================] - 0s 6ms/step - loss: 2.9676 - val_loss: 1.9928
# Epoch 480/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0762 - val_loss: 1.9786
# Epoch 481/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1375 - val_loss: 1.7142
# Epoch 482/500
# 37/37 [==============================] - 0s 6ms/step - loss: 2.9657 - val_loss: 1.6814
# Epoch 483/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0664 - val_loss: 3.8207
# Epoch 484/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2671 - val_loss: 2.1217
# Epoch 485/500
# 37/37 [==============================] - 0s 6ms/step - loss: 2.9983 - val_loss: 1.8477
# Epoch 486/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.3198 - val_loss: 2.6445
# Epoch 487/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1259 - val_loss: 1.8309
# Epoch 488/500
# 37/37 [==============================] - 0s 6ms/step - loss: 2.9472 - val_loss: 1.6960
# Epoch 489/500
# 37/37 [==============================] - 0s 6ms/step - loss: 2.9364 - val_loss: 1.8503
# Epoch 490/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0870 - val_loss: 1.7077
# Epoch 491/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0412 - val_loss: 1.7676
# Epoch 492/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2345 - val_loss: 1.9770
# Epoch 493/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0693 - val_loss: 2.5151
# Epoch 494/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0527 - val_loss: 1.8645
# Epoch 495/500
# 37/37 [==============================] - 0s 6ms/step - loss: 2.8401 - val_loss: 2.7480
# Epoch 496/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.0658 - val_loss: 1.8586
# Epoch 497/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2645 - val_loss: 1.9203
# Epoch 498/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1223 - val_loss: 3.1126
# Epoch 499/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.2527 - val_loss: 3.3350
# Epoch 500/500
# 37/37 [==============================] - 0s 6ms/step - loss: 3.1711 - val_loss: 2.5760

# %%
def plot_train_history(history, title):
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(loss))

    plt.figure(figsize=(10,5))

    plt.plot(epochs, loss, 'b', label='Training loss')
    plt.plot(epochs, val_loss, 'r', label='Validation loss')
    plt.title(title)
    plt.legend()
    plt.savefig('../Images/' + title)

    plt.show()

# %%
plot_train_history(LSTM_price_model_history, 'LSTM_Univariate_Price_Model_Training_and_Validation_loss')

# %% [markdown]
# ## Predictions from LSTM Univariate

# %%
y_pred = LSTM_price_model.predict(x_test)
y_pred
# Out:
# array([[95.09295 ],
#        [92.64662 ],
#        [90.2842  ],
#        [88.78268 ],
#        [87.73541 ],
#        [86.54813 ],
#        [83.6874  ],
#        [81.8816  ],
#        [81.8989  ],
#        [82.87177 ],
#        [82.52442 ],
#        [81.358574],
#        [82.64901 ],
#        [82.44227 ],
#        [82.1618  ],
#        [83.748474],
#        [87.366844],
#        [88.355965],
#        [87.29129 ],
#        [85.51432 ],
#        [82.7752  ],
#        [81.61667 ],
#        [81.09026 ],
#        [82.733345],
#        [81.86645 ],
#        [85.46873 ],
#        [86.13172 ],
#        [87.028244],
#        [87.956505]], dtype=float32)

# %%
# Plot the predictions (one step ahead) against the test data
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(pd.to_datetime(time_series[-len(y_pred):]), y_pred, 'b.-', label='predictions', lw=0.5)
ax.plot(pd.to_datetime(time_series[-len(y_pred):]), y_test, 'r.', label='actual')
ax.set_title('Univariate LSTM Model predictions over the test data')
fig.savefig('../Images/UnivariateLSTMModelPredictions_testdata')
ax.legend();

# %%
# Calculating MAPE (Mean Absolute Precentage Error)
def mape(actual, pred): 
    actual, pred = np.array(actual), np.array(pred)
    return np.mean(np.abs((actual - pred) / actual)) * 100

# %%
# Calaculate MAPE
print(f'MAPE for known data (before 2020) = {mape(price_series, y_pred)}')
# Out:
# MAPE for known data (before 2020) = 11.09391105939156

# %% [markdown]
# ## Try again with scaled data

# %%
# Data Loader Parameters
BATCH_SIZE = 32
BUFFER_SIZE = 10 # 
TRAIN_SPLIT = 300 # about 70%

# LSTM Parameters
EVALUATION_INTERVAL = 300
EPOCHS = 500
PATIENCE = 100

# Reproducibility
SEED = 13
# tf.random.set_seed(SEED)

n_prev = 10

# %%
# Load the data again
df_CHN_CTC_leaf = pd.read_csv('../Data/df_CHN_CTC_leaf.csv', header=0, index_col=0)
# chop out 2020 data
df_CHN_CTC_leaf = df_CHN_CTC_leaf[pd.to_datetime(df_CHN_CTC_leaf.index) < pd.to_datetime('2020-01-01')]
# Plot it
plot_oqty_sqty_avgp(df_CHN_CTC_leaf, 'ctc_leaf', 'Cochin')

# %%
def univariate_data(dataset, start_index, end_index, history_size, target_size):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i)
        # Reshape data from (history_size,) to (history_size, 1)
        data.append(np.reshape(dataset[indices], (history_size, 1)))
        labels.append(dataset[i+target_size])
        
    return np.array(data), np.array(labels)

# %%
df_CHN_CTC_leaf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 412 entries, 14-Jan-12 to 28-Dec-19
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   year                412 non-null    int64
#  1   serial_no           412 non-null    int64
#  2   ctc_leaf_offer_qty  412 non-null    float64
#  3   ctc_leaf_sold_qty   412 non-null    float64
#  4   ctc_leaf_avg_price  412 non-null    float64
# dtypes: float64(3), int64(2)
# memory usage: 19.3+ KB

# %%
# Prepare the data for only the average price

# %%
uni_data = df_CHN_CTC_leaf['ctc_leaf_avg_price']
uni_data.index = df_CHN_CTC_leaf.index

# %%
uni_data.plot(subplots=True)
plt.show()
uni_data = uni_data.values

# %%
# Scale only the train data
uni_train_mean = uni_data[:TRAIN_SPLIT].mean()
uni_train_std = uni_data[:TRAIN_SPLIT].std()
uni_data = (uni_data-uni_train_mean)/uni_train_std

# %%
# Create the data for the univariate model which will be given the last n_prev weeks' price observations, 
# and needs to learn to predict the temperature at the next week.
univariate_past_history = n_prev
univariate_future_target = 3

x_train_uni, y_train_uni = univariate_data(dataset=uni_data,
                                           start_index=0,
                                           end_index=TRAIN_SPLIT,
                                           history_size=univariate_past_history,
                                           target_size=univariate_future_target)
x_val_uni, y_val_uni = univariate_data(dataset=uni_data,
                                       start_index=TRAIN_SPLIT,
                                       end_index=None,
                                       history_size=univariate_past_history,
                                       target_size=univariate_future_target)

# %%
print("In:")
print(uni_data.shape)
print(uni_data[:5])

print("\nOut")
print(x_train_uni.shape)
print(y_train_uni[0])

print(x_train_uni.shape[0] / uni_data.shape[0])
# Out:
# In:
# (412,)
# [-1.44523537 -1.26413727 -1.21015611 -1.21886275 -1.3407557 ]
#
# Out
# (290, 10, 1)
# -0.9472156014155011
# 0.7038834951456311

# %%
print ('Single window of past history. Shape: {}'.format(x_train_uni[0].shape))
print (x_train_uni[0])
print ('\n Target price to predict. Shape: {}'.format(y_train_uni[0].shape))
print (y_train_uni[0])
# Out:
# Single window of past history. Shape: (10, 1)
# [[-1.44523537]
#  [-1.26413727]
#  [-1.21015611]
#  [-1.21886275]
#  [-1.3407557 ]
#  [-1.55493902]
#  [-1.28067989]
#  [-1.20754412]
#  [-1.25107731]
#  [-1.02296336]]
#
#  Target price to predict. Shape: ()
# -0.9472156014155011

# %%
def create_time_steps(length):
    return list(range(-length, 0))

# %%
def show_plot(plot_data, delta, title):
    labels = ['History', 'True Future', 'Model Prediction']
    marker = ['.-', 'rx', 'go']
    time_steps = create_time_steps(plot_data[0].shape[0])
    if delta:
        future = delta
    else:
        future = 0

    plt.title(title)
    for i, x in enumerate(plot_data):
        if i:
            plt.plot(future, plot_data[i], marker[i], markersize=10,
                   label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
        plt.legend()
        plt.xlim([time_steps[0], (future+5)*2])
        plt.xlabel('Time-Step')
        plt.figsize = (18,6)
    
    return plt

# %%
show_plot([x_train_uni[0], y_train_uni[0]], 3, 'Sample Example');

# %% [markdown]
# #### Baseline
# Before proceeding to train a model, let's first set a simple baseline. Given an input point, the baseline method looks at all the history and predicts the next point to be the average of the last 20 observations.

# %%
def baseline(history):
    return np.mean(history)

# %%
show_plot([x_train_uni[0], y_train_uni[0], baseline(x_train_uni[0])], 3,
           'Baseline Prediction Example');

# %%
# Let's now use tf.data to shuffle, batch, and cache the dataset.
train_univariate = tf.data.Dataset.from_tensor_slices((x_train_uni, y_train_uni))
train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_univariate = tf.data.Dataset.from_tensor_slices((x_val_uni, y_val_uni))
val_univariate = val_univariate.batch(BATCH_SIZE).repeat()

# %%
x_train_uni.shape
# Out:
# (290, 10, 1)

# %%
# Set up the model
uni_lstm_model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(32, input_shape=x_train_uni.shape[-2:], return_sequences=True),
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.LSTM(32, input_shape=x_train_uni.shape[-2:], return_sequences=False),
    tf.keras.layers.Dense(1, activation='relu')
])

uni_lstm_model.compile(optimizer='adam', loss='mape')

# %%
# LSTM_price_model = keras.Sequential()
# LSTM_price_model.add(keras.layers.LSTM(52, input_shape=(n_prev, 1), return_sequences=True))
# LSTM_price_model.add(keras.layers.Dropout(0.1))
# LSTM_price_model.add(keras.layers.LSTM(52, return_sequences=False))
# LSTM_price_model.add(keras.layers.Dense(1, activation='relu')) # 'linear'

# LSTM_price_model.compile(optimizer='adam', loss='mse')

# %%
for x, y in val_univariate.take(1):
    
    print(uni_lstm_model.predict(x).shape)
# Out:
# (32, 1)

# %%
tf.__version__
# Out:
# '2.3.0'

# %%
500
# 300/300 [==============================] - 2s 6ms/step - loss: 59.0102 - val_loss: 159.2492
# Epoch 90/500
# 300/300 [==============================] - 2s 6ms/step - loss: 59.9685 - val_loss: 150.2315
# Epoch 91/500
# 300/300 [==============================] - 2s 6ms/step - loss: 58.6144 - val_loss: 151.2511
# Epoch 92/500
# 300/300 [==============================] - 2s 6ms/step - loss: 58.3775 - val_loss: 158.4005
# Epoch 93/500
# 300/300 [==============================] - 2s 6ms/step - loss: 58.8047 - val_loss: 149.7222
# Epoch 94/500
# 300/300 [==============================] - 2s 6ms/step - loss: 58.9433 - val_loss: 159.1836
# Epoch 95/500
# 300/300 [==============================] - 2s 6ms/step - loss: 63.8877 - val_loss: 163.4392
# Epoch 96/500
# 300/300 [==============================] - 2s 6ms/step - loss: 59.3373 - val_loss: 147.6270
# Epoch 97/500
# 300/300 [==============================] - 2s 6ms/step - loss: 58.4935 - val_loss: 151.7015
# Epoch 98/500
# 300/300 [==============================] - 2s 6ms/step - loss: 58.1675 - val_loss: 147.9978
# Epoch 99/500
# 300/300 [==============================] - 2s 6ms/step - loss: 58.8462 - val_loss: 146.1566
# Epoch 100/500
# 300/300 [==============================] - 2s 6ms/step - loss: 57.9788 - val_loss: 151.8367
# Epoch 101/500
# 300/300 [==============================] - 2s 6ms/step - loss: 58.5928 - val_loss: 144.2558
# Epoch 102/500
# 300/300 [==============================] - 2s 6ms/step - loss: 58.8619 - val_loss: 148.1633
# Epoch 103/500
# 300/300 [==============================] - 2s 6ms/step - loss: 59.2149 - val_loss: 149.3142
# Epoch 104/500
# 300/300 [==============================] - 2s 6ms/step - loss: 58.1717 - val_loss: 150.0369
# Epoch 105/500
# 300/300 [==============================] - 2s 6ms/step - loss: 57.7967 - val_loss: 147.4091
# Epoch 106/500
# 300/300 [==============================] - 2s 6ms/step - loss: 58.2467 - val_loss: 146.0821
# Epoch 107/500
# 300/300 [==============================] - 2s 6ms/step - loss: 58.6973 - val_loss: 153.6132
# Epoch 108/500
# 300/300 [==============================] - 2s 6ms/step - loss: 57.5615 - val_loss: 150.9413
# Epoch 109/500
# 300/300 [==============================] - 2s 6ms/step - loss: 59.0371 - val_loss: 152.1938
# Epoch 110/500
# 300/300 [==============================] - 2s 6ms/step - loss: 57.3798 - val_loss: 150.7588
# Epoch 111/500
# 300/300 [==============================] - 2s 6ms/step - loss: 58.1087 - val_loss: 124.1819
# Epoch 112/500
# 300/300 [==============================] - 2s 6ms/step - loss: 58.5891 - val_loss: 122.9256
# Epoch 113/500
# 300/300 [==============================] - 2s 6ms/step - loss: 59.3122 - val_loss: 130.1085
# Epoch 114/500
# 300/300 [==============================] - 2s 6ms/step - loss: 57.7723 - val_loss: 131.8091
# Epoch 115/500
# 300/300 [==============================] - 2s 6ms/step - loss: 57.0515 - val_loss: 135.9564
# Epoch 116/500
# 300/300 [==============================] - 2s 6ms/step - loss: 56.8924 - val_loss: 130.6487
# Epoch 117/500
# 300/300 [==============================] - 2s 6ms/step - loss: 56.8789 - val_loss: 135.3911

# %% [markdown]
# ### Predict

# %%
for x, y in val_univariate.take(10):
    plot = show_plot([x[0].numpy(), y[0].numpy(),
                    uni_lstm_model.predict(x)[0]], 3, 'Simple LSTM model')
    plot.show()

# %% [markdown]
# #### Poor results for univariate!

# %% [markdown]
# ## Multivariate

# %%
# Data Loader Parameters
BATCH_SIZE = 32
BUFFER_SIZE = 10 # 10000
TRAIN_SPLIT = 300 # ~ 70:30 300K out of 420K

# Reproducibility
SEED = 13
# tf.random.set_seed(SEED)

n_prev = 10

# %% [markdown]
# First for 3 features from the same tea category (CTC Leaf): ctc_leaf_avg_price, ctc_leaf_offer_qty & ctc_leaf_sold_qty.

# %%
features_considered = ['ctc_leaf_offer_qty', 'ctc_leaf_sold_qty', 'ctc_leaf_avg_price']

# %%
features = df_CHN_CTC_leaf[features_considered]
features.index = df_CHN_CTC_leaf.index
features.head()
# Out:
#              ctc_leaf_offer_qty  ctc_leaf_sold_qty  ctc_leaf_avg_price
# week_ending
# 14-Jan-12               83325.0            77015.0               68.03
# 21-Jan-12               71897.0            68187.0               70.11
# 28-Jan-12               91279.0            78695.0               70.73
# 4-Feb-12                83746.0            71188.0               70.63
# 11-Feb-12               89650.0            85480.0               69.23

# %%
features.plot(subplots=True)
plt.savefig('../Images/AllFeatures')

# %% [markdown]
# Standardize the training dataset using the mean and standard deviation of the training data.

# %%
TRAIN_SPLIT
# Out:
# 300

# %%
dataset = features.values
data_mean = dataset[:TRAIN_SPLIT].mean(axis=0)
data_std = dataset[:TRAIN_SPLIT].std(axis=0)
#dataset = (dataset-data_mean)/data_std

# %%
pd.DataFrame(dataset, columns = features.columns, index= features.index).head()
# Out:
#              ctc_leaf_offer_qty  ctc_leaf_sold_qty  ctc_leaf_avg_price
# week_ending
# 14-Jan-12               83325.0            77015.0               68.03
# 21-Jan-12               71897.0            68187.0               70.11
# 28-Jan-12               91279.0            78695.0               70.73
# 4-Feb-12                83746.0            71188.0               70.63
# 11-Feb-12               89650.0            85480.0               69.23

# %% [markdown]
# #### Single step model
# In a single step setup, the model learns to predict a single point in the future based on some history provided.
#
# The below function performs the windowing task as below, however, here it samples the past observation based on the step size given.

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step)
        data.append(dataset[indices])

        if single_step:
            labels.append(target[i+target_size])
        else:
            labels.append(target[i:i+target_size])

    return np.array(data), np.array(labels)

# %% [markdown]
# The model is shown data from the last n_prev weeks.
# For the single step prediction model, the label for a datapoint is the price 1 weeks into the future.

# %%
past_history = n_prev # 10 weeks
future_target = 3 # after 3 weeks
STEP = 1 # take consecutive observations, no skips

x_train_single, y_train_single = multivariate_data(dataset, dataset[:, 2], 0,
                                                   TRAIN_SPLIT, past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(dataset, dataset[:, 2],
                                               TRAIN_SPLIT, None, past_history,
                                               future_target, STEP,
                                               single_step=True)

# %% [markdown]
# Let's look at a single data-point.

# %%
print(x_train_single.shape)
print ('Single window of past history : {}'.format(x_train_single[0].shape))
print(x_train_single.shape[-2:])
y_train_single.shape
# Out:
# (290, 10, 3)
# Single window of past history : (10, 3)
# (10, 3)
# (290,)

# %%
train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()

# %% [markdown]
# ### Setup Multivariate Model -Single output

# %%
single_step_model = tf.keras.models.Sequential()

single_step_model.add(tf.keras.layers.LSTM(32, input_shape=x_train_single.shape[-2:], return_sequences=True))

single_step_model.add(keras.layers.Dropout(0.1))

single_step_model.add(keras.layers.LSTM(32, input_shape=x_train_single.shape[-2:], return_sequences=False))

single_step_model.add(tf.keras.layers.Dense(1))

single_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='mape')

# %% [markdown]
# Let's check out a sample prediction.

# %%
for x, y in val_data_single.take(1):
    print(single_step_model.predict(x).shape)
# Out:
# (32, 1)

# %%
# LSTM Parameters
EVALUATION_INTERVAL = 200
EPOCHS = 300
PATIENCE = 300

# %%
print(f"Evaluation Threshold: {EVALUATION_INTERVAL}",
      f"Epochs: {EPOCHS}", sep="\n")

early_stopping = EarlyStopping(monitor='val_loss', patience = PATIENCE, restore_best_weights=True)
single_step_history = single_step_model.fit(train_data_single,
                                            epochs=EPOCHS,
                                            steps_per_epoch=EVALUATION_INTERVAL,
                                            validation_data=val_data_single,
                                
300
# 200/200 [==============================] - 1s 6ms/step - loss: 2.5393 - val_loss: 8.2939
# Epoch 291/300
# 200/200 [==============================] - 1s 6ms/step - loss: 2.5116 - val_loss: 8.1350
# Epoch 292/300
# 200/200 [==============================] - 1s 6ms/step - loss: 2.5507 - val_loss: 8.3242
# Epoch 293/300
# 200/200 [==============================] - 1s 6ms/step - loss: 2.4752 - val_loss: 8.3648
# Epoch 294/300
# 200/200 [==============================] - 1s 6ms/step - loss: 2.5192 - val_loss: 8.5427
# Epoch 295/300
# 200/200 [==============================] - 1s 6ms/step - loss: 2.5177 - val_loss: 8.0413
# Epoch 296/300
# 200/200 [==============================] - 1s 6ms/step - loss: 2.5556 - val_loss: 8.8288
# Epoch 297/300
# 200/200 [==============================] - 1s 6ms/step - loss: 2.5899 - val_loss: 8.4167
# Epoch 298/300
# 200/200 [==============================] - 1s 6ms/step - loss: 2.5651 - val_loss: 8.2042
# Epoch 299/300
# 200/200 [==============================] - 1s 6ms/step - loss: 2.4790 - val_loss: 8.0417
# Epoch 300/300
# 200/200 [==============================] - 1s 6ms/step - loss: 2.5002 - val_loss: 8.4605

# %%
def plot_train_history(history, title):
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(loss))

    plt.figure()

    plt.plot(epochs, loss, 'b', label='Training loss')
    plt.plot(epochs, val_loss, 'r', label='Validation loss')
    plt.title(title)
    plt.legend()
    plt.savefig('../Images/' + title + '.png')
    plt.show()

# %%
plot_train_history(single_step_history,
                   'Single_Step_Training_and_Validation_loss')

# %% [markdown]
# #### Predict a single step future
# Now that the model is trained, let's make a few sample predictions. The model is given the history of three features over the past n_prev weeks, and is to predict the price 3 weeks into the future. The plot only displays the past prices. Since the prediction is made 3 weeks into the future, there is a gap between the history and prediction).

# %%
i = 1
for x, y in val_data_single.take(3):
    plot = show_plot([x[2][:, 2].numpy(), y[2].numpy(),
                    single_step_model.predict(x)[2]], 3,
                   'Single Step Prediction')
    plt.title(f'Sample Single Step Prediction - MAPE = {mape(y[2].numpy(), single_step_model.predict(x)[2] )}')
    plt.savefig('../Images/SampleSingeStepPredictions' + str(i))
    i += 1
    plot.show()

# %% [markdown]
# ### Multi-Step model
# In a multi-step prediction model, given a past history, the model needs to learn to predict a range of future values. Thus, unlike a single step model, where only a single future point is predicted, a multi-step model predict a sequence of the future.
#
# For the multi-step model, the training data again consists of prices over the past n_prev weeks. However, here, the model needs to learn to predict the prices for the next 3 weeks. The output is 3 predictions. For this task, the dataset needs to be prepared accordingly, thus the first step is just to create it again, but with a different target window.

# %%
past_history = n_prev # 10 weeks 
future_target = 3 # after 3 weeks 
STEP = 3 # no gap between last observation and first prediction

x_train_multi, y_train_multi = multivariate_data(dataset, dataset[:, 2], 0,
                                                 TRAIN_SPLIT, past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_data(dataset, dataset[:, 2],
                                             TRAIN_SPLIT, None, past_history,
                                             future_target, STEP)

# %% [markdown]
# Let's check out a sample data-point.

# %%
print (x_train_multi.shape,
       y_train_multi.shape,
       'Single window of past history : {}'.format(x_train_multi[2].shape),
       'Target temperature to predict : {}'.format(y_train_multi[2].shape),
       sep='\n')
# Out:
# (290, 4, 3)
# (290, 3)
# Single window of past history : (4, 3)
# Target temperature to predict : (3,)

# %%
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %% [markdown]
# Plotting a sample data-point.

# %%
def multi_step_plot(history, true_future, prediction, sample_number=''):
    plt.figure(figsize=(15, 4))
    num_in = create_time_steps(len(history))
    num_out = len(true_future)

    plt.plot(num_in, np.array(history[:, 2]), label='History')
    plt.plot(np.arange(num_out)/STEP, np.array(true_future), 'bo',
           label='True Future')
    if prediction.any():
        plt.plot(np.arange(num_out)/STEP, np.array(prediction), 'ro',
                 label='Predicted Future')
    plt.legend(loc='upper left')
    plt.title(f'Multi Step Prediction - MAPE = {mape(true_future, prediction)}')
    plt.savefig('../Images/SampleMultiStepPredictions' + sample_number)
    plt.show()

# %%
# for x, y in train_data_multi.take(1):
#     multi_step_plot(x[2], y[2], np.array([0]))

# %% [markdown]
# Since the task here is a bit more complicated than the previous task, the model now consists of two LSTM layers. Finally, since 3 predictions are made, the dense layer outputs 3 predictions.

# %% [markdown]
# ### Setup Multivariate Model -Multiple steps output

# %%
multi_step_model = tf.keras.models.Sequential()

multi_step_model.add(tf.keras.layers.LSTM(32, input_shape=x_train_single.shape[-2:], return_sequences=True))

multi_step_model.add(keras.layers.Dropout(0.1))

multi_step_model.add(keras.layers.LSTM(32, input_shape=x_train_single.shape[-2:], return_sequences=False))

multi_step_model.add(tf.keras.layers.Dense(3))

# multi_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(clipvalue=1.0), loss='mape')
multi_step_model.compile(optimizer='adam', loss='mape')

print(multi_step_model.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (None, 10, 32)            4608
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 10, 32)            0
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 13,027
# Trainable params: 13,027
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Let's see how the model predicts before it trains.

# %%
for x, y in val_data_multi.take(1):
    print (multi_step_model.predict(x).shape)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 10, 3) for input Tensor("lstm_6_input:0", shape=(None, 10, 3), dtype=float32), but it was called on an input with incompatible shape (32, 4, 3).
# (32, 3)

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience = 100, restore_best_weights=True)
multi_step_history = multi_step_model.fit(train_data_multi,
                                          epochs=EPOCHS,
                                          steps_per_epoch=EVALUATION_INTERVAL,
                                          validation_data=val_data_multi,
                                          validation_steps=EVALUATION_INTERVAL,
                                          callbacks=[early_stopping])
# Out:
# Epoch 1/300
# WARNING:tensorflow:Model was constructed with shape (None, 10, 3) for input Tensor("lstm_6_input:0", shape=(None, 10, 3), dtype=float32), but it was called on an input with incompatible shape (None, 4, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 10, 3) for input Tensor("lstm_6_input:0", shape=(None, 10, 3), dtype=float32), but it was called on an input with incompatible shape (None, 4, 3).
# 190/200 [===========================>..] - ETA: 0s - loss: 92.8964WARNING:tensorflow:Model was constructed with shape (None, 10, 3) for input Tensor("lstm_6_input:0", shape=(None, 10, 3), dtype=float32), but it was called on an input with incompatible shape (None, 4, 3).
# 200/200 [==============================] - 1s 7ms/step - loss: 92.5564 - val_loss: 86.6668
# Epoch 2/300
# 200/200 [==============================] - 1s 5ms/step - loss: 81.2959 - val_loss: 78.2790
# Epoch 3/300
# 200/200 [==============================] - 1s 5ms/step - loss: 72.7105 - val_loss: 70.4276
# Epoch 4/300
# 200/200 [==============================] - 1s 5ms/step - loss: 64.4567 - val_loss: 62.7638
# Epoch 5/300
# 200/200 [==============================] - 1s 5ms/step - loss: 56.3536 - val_loss: 55.1968
# Epoch 6/300
# 200/200 [==============================] - 1s 5ms/step - loss: 48.3174 - val_loss: 47.6793
# Epoch 7/300
# 200/200 [==============================] - 1s 5ms/step - loss: 40.3359 - val_loss: 40.2029
# Epoch 8/300
# 200/200 [==============================] - 1s 4ms/step - loss: 32.3852 - val_loss: 32.7436
# Epoch 9/300
# 200/200 [==============================] - 1s 5ms/step - loss: 24.4755 - val_loss: 25.3563
# Epoch 10/300
# 200/200 [==============================] - 1s 5ms/step - loss: 17.5332 - val_loss: 19.1445
# Epoch 11/300
# 200/200 [==============================] - 1s 4ms/step - loss: 14.0211 - val_loss: 15.1283
# Epoch 12/300
# 200/200 [==============================] - 1s 5ms/step - loss: 12.6551 - val_loss: 12.5504
# Epoch 13/300
# 200/200 [==============================] - 1s 5ms/step - loss: 12.0048 - val_loss: 10.7967
# Epoch 14/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.7229 - val_loss: 9.9627
# Epoch 15/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.6355 - val_loss: 9.5088
# Epoch 16/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.6051 - val_loss: 9.3093
# Epoch 17/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.5885 - val_loss: 9.1615
# Epoch 18/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11
300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3266 - val_loss: 8.4739
# Epoch 82/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3308 - val_loss: 8.5538
# Epoch 83/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3476 - val_loss: 8.6011
# Epoch 84/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3305 - val_loss: 8.5099
# Epoch 85/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3392 - val_loss: 8.5795
# Epoch 86/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3191 - val_loss: 8.6298
# Epoch 87/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3328 - val_loss: 8.5671
# Epoch 88/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3496 - val_loss: 8.5495
# Epoch 89/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3313 - val_loss: 8.5025
# Epoch 90/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3115 - val_loss: 8.4954
# Epoch 91/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3284 - val_loss: 8.5164
# Epoch 92/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3258 - val_loss: 8.5973
# Epoch 93/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3348 - val_loss: 8.5316
# Epoch 94/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3410 - val_loss: 8.5808
# Epoch 95/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3218 - val_loss: 8.6605
# Epoch 96/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3587 - val_loss: 8.5068
# Epoch 97/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3417 - val_loss: 8.5494
# Epoch 98/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3229 - val_loss: 8.5786
# Epoch 99/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3337 - val_loss: 8.5886
# Epoch 100/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3522 - val_loss: 8.5431
# Epoch 101/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3232 - val_loss: 8.4952
# Epoch 102/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3266 - val_loss: 8.4955
# Epoch 103/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3126 - val_loss: 8.5274
# Epoch 104/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3203 - val_loss: 8.5589
# Epoch 105/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3239 - val_loss: 8.5755
# Epoch 106/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3470 - val_loss: 8.6519
# Epoch 107/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3220 - val_loss: 8.4677
# Epoch 108/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3439 - val_loss: 8.5059
# Epoch 109/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3231 - val_loss: 8.6537
# Epoch 110/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3167 - val_loss: 8.5190
# Epoch 111/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3312 - val_loss: 8.5489
# Epoch 112/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3092 - val_loss: 8.5111
# Epoch 113/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3245 - val_loss: 8.5628
# Epoch 114/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3336 - val_loss: 8.6330
# Epoch 115/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3376 - val_loss: 8.5674
# Epoch 116/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3235 - val_loss: 8.5823
# Epoch 117/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3355 - val_loss: 8.5908
# Epoch 118/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3148 - val_loss: 8.4861
# Epoch 119/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.2945 - val_loss: 8.5331
# Epoch 120/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3248 - val_loss: 8.4759
# Epoch 121/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3107 - val_loss: 8.5319
# Epoch 122/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3148 - val_loss: 8.5514
# Epoch 123/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3272 - val_loss: 8.4287
# Epoch 124/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3291 - val_loss: 8.6245
# Epoch 125/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3218 - val_loss: 8.5482
# Epoch 126/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3219 - val_loss: 8.5205
# Epoch 127/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3115 - val_loss: 8.5658
# Epoch 128/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3258 - val_loss: 8.5297
# Epoch 129/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3234 - val_loss: 8.5212
# Epoch 130/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3204 - val_loss: 8.5191
# Epoch 131/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3215 - val_loss: 8.5784
# Epoch 132/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3290 - val_loss: 8.5908
# Epoch 133/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3410 - val_loss: 8.5600
# Epoch 134/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3494 - val_loss: 8.5527
# Epoch 135/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3196 - val_loss: 8.4881
# Epoch 136/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.2935 - val_loss: 8.5403
# Epoch 137/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3229 - val_loss: 8.7233
# Epoch 138/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3316 - val_loss: 8.4793
# Epoch 139/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3141 - val_loss: 8.5961
# Epoch 140/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3394 - val_loss: 8.6598
# Epoch 141/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3143 - val_loss: 8.5605
# Epoch 142/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3294 - val_loss: 8.6109
# Epoch 143/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3163 - val_loss: 8.5966
# Epoch 144/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3215 - val_loss: 8.6338
# Epoch 145/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3021 - val_loss: 8.4331
# Epoch 146/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3334 - val_loss: 8.5467
# Epoch 147/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3303 - val_loss: 8.5319
# Epoch 148/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3019 - val_loss: 8.5848
# Epoch 149/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3318 - val_loss: 8.4631
# Epoch 150/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3193 - val_loss: 8.5622
# Epoch 151/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3158 - val_loss: 8.5475
# Epoch 152/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3203 - val_loss: 8.6627
# Epoch 153/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3100 - val_loss: 8.5506
# Epoch 154/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3334 - val_loss: 8.5827
# Epoch 155/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3343 - val_loss: 8.6693
# Epoch 156/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3118 - val_loss: 8.5635
# Epoch 157/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3312 - val_loss: 8.4632
# Epoch 158/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3298 - val_loss: 8.5107
# Epoch 159/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3227 - val_loss: 8.5598
# Epoch 160/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3458 - val_loss: 8.5448
# Epoch 161/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3153 - val_loss: 8.5551
# Epoch 162/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3312 - val_loss: 8.4547
# Epoch 163/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3180 - val_loss: 8.6257
# Epoch 164/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3401 - val_loss: 8.4049
# Epoch 165/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3486 - val_loss: 8.5284
# Epoch 166/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3248 - val_loss: 8.5423
# Epoch 167/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3418 - val_loss: 8.5774
# Epoch 168/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3269 - val_loss: 8.5458
# Epoch 169/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3153 - val_loss: 8.5516
# Epoch 170/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3129 - val_loss: 8.5200
# Epoch 171/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3378 - val_loss: 8.5163
# Epoch 172/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3017 - val_loss: 8.5595
# Epoch 173/300
# 200/200 [==============================] - 1s 4ms/step - loss: 11.3173 - val_loss: 8.6230
# Epoch 174/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3371 - val_loss: 8.5646
# Epoch 175/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3173 - val_loss: 8.6664
# Epoch 176/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3441 - val_loss: 8.5510
# Epoch 177/300
# 200/200 [==============================] - 1s 5ms/step - loss: 11.3240 - val_loss: 8.7458

# %%
plot_train_history(multi_step_history, 'Multi_Step_Training_and_Validation_loss')

# %% [markdown]
# Predict a multi-step future
# Let's now have a look at how well your network has learnt to predict the future.

# %%
multi_step_model.predict(x)[0]
# Out:
# array([82.96099 , 83.138405, 83.54748 ], dtype=float32)

# %%
i = 1
for x, y in val_data_multi.take(3):
    multi_step_plot(x[0], y[0], multi_step_model.predict(x)[0], str(i))
    i += 1
#     print(f'MAPE = {mape(y[0], multi_step_model.predict(x)[0])}')

# %%
print(f'MAPE = {mape(y[0], multi_step_model.predict(x)[0])}')
#mape(y[0], multi_step_model.predict(x)[0])
# Out:
# MAPE = 13.543099164962769

# %% [markdown]
# ### Multi-Step, Multi-Input, and Multi-Output - (Work in progress)

# %%
dataset
# Out:
# array([[ 0.51135842,  1.39390078, -1.44523537],
#        [-0.12728076,  0.8348993 , -1.26413727],
#        [ 0.95585754,  1.50028076, -1.21015611],
#        ...,
#        [-2.53748979, -2.62314664,  0.10715841],
#        [-2.21353185, -2.21890271,  0.1533036 ],
#        [-1.9473018 , -2.1520353 ,  0.1968368 ]])

# %%
dataset = features.values
data_mean = dataset[:TRAIN_SPLIT].mean(axis=0)
data_std = dataset[:TRAIN_SPLIT].std(axis=0)
dataset = (dataset-data_mean)/data_std

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential

# %%
def multivariate_multioutput_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step)
        data.append(dataset[indices])

        if single_step:
            labels.append(target[i+target_size])
        else:
            labels.append(target[i:i+target_size])

    return np.array(data)[:,:,:,np.newaxis,np.newaxis], np.array(labels)[:,:,:,np.newaxis,np.newaxis]

def multi_step_output_plot(history, true_future, prediction, sample_number=''):
    plt.figure(figsize=(15, 5))
    num_in = create_time_steps(len(history))
    num_out = len(true_future)
    
    for i, (var, c) in enumerate(zip(features.columns[:3], ['r', 'b', 'g'])):
        plt.plot(num_in, np.array(history[:, i]), c, label=var)
        plt.plot(np.arange(num_out)/STEP, np.array(true_future[:,i]), c+'o', markersize=5, alpha=0.5,
               label=f"True {var.title()}")
        if prediction.any():
            plt.plot(np.arange(num_out)/STEP, np.array(prediction[:,i]), '*', markersize=5, alpha=0.5,
                     label=f"Predicted {var.title()}")
    
    plt.legend(loc='upper left')
    plt.show()

# %%
future_target = 3
x_train_multi, y_train_multi = multivariate_multioutput_data(dataset[:,:2], dataset[:,:2], 0,
                                                 TRAIN_SPLIT, past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_multioutput_data(dataset[:,:2], dataset[:, :2],
                                             TRAIN_SPLIT, None, past_history,
                                             future_target, STEP)

# %%
print (x_train_multi.shape,
       y_train_multi.shape,
       x_val_multi.shape,
       y_val_multi.shape,
       'Single window of past history : {}'.format(x_train_multi[0].shape),
       'Target price to predict : {}'.format(y_train_multi[0].shape),
       sep='\n')
# Out:
# (290, 4, 2, 1, 1)
# (290, 3, 2, 1, 1)
# (99, 4, 2, 1, 1)
# (99, 3, 2, 1, 1)
# Single window of past history : (4, 2, 1, 1)
# Target price to predict : (3, 2, 1, 1)

# %%
BATCH_SIZE = 128

train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
# for x, y in val_data_multi.take(3):
#     multi_step_output_plot(np.squeeze(x[0]), np.squeeze(y[0]), np.array([0]))

# %% [markdown]
# Convolutional LSTM
# As taken from the paper.

# %%
def build_model(input_timesteps, output_timesteps, num_links, num_inputs):
    # COPY PASTE
    # https://github.com/niklascp/bus-arrival-convlstm/blob/master/jupyter/ConvLSTM_3x15min_10x64-5x64-10x64-5x64-Comparison.ipynb
    
    model = Sequential()
    model.add(BatchNormalization(name = 'batch_norm_0', input_shape = (input_timesteps, num_inputs, 1, 1)))
    model.add(ConvLSTM2D(name ='conv_lstm_1',
                         filters = 64, kernel_size = (10, 1),                       
                         padding = 'same', 
                         return_sequences = True))
    
    model.add(Dropout(0.30, name = 'dropout_1'))
    model.add(BatchNormalization(name = 'batch_norm_1'))

    model.add(ConvLSTM2D(name ='conv_lstm_2',
                         filters = 64, kernel_size = (5, 1), 
                         padding='same',
                         return_sequences = False))
    
    model.add(Dropout(0.20, name = 'dropout_2'))
    model.add(BatchNormalization(name = 'batch_norm_2'))
    
    model.add(Flatten())
    model.add(RepeatVector(output_timesteps))
    model.add(Reshape((output_timesteps, num_inputs, 1, 64)))
    
    model.add(ConvLSTM2D(name ='conv_lstm_3',
                         filters = 64, kernel_size = (10, 1), 
                         padding='same',
                         return_sequences = True))
    
    model.add(Dropout(0.20, name = 'dropout_3'))
    model.add(BatchNormalization(name = 'batch_norm_3'))
    
    model.add(ConvLSTM2D(name ='conv_lstm_4',
                         filters = 64, kernel_size = (5, 1), 
                         padding='same',
                         return_sequences = True))
    
    model.add(TimeDistributed(Dense(units=1, name = 'dense_1', activation = 'relu')))
    model.add(Dense(units=1, name = 'dense_2', activation = 'linear'))

#     optimizer = RMSprop() #lr=0.0001, rho=0.9, epsilon=1e-08, decay=0.9)
#     optimizer = tf.keras.optimizers.Adam(0.1)
    optimizer = tf.keras.optimizers.RMSprop(lr=0.004, clipvalue=1.0)
    model.compile(loss = "mape", optimizer = optimizer, metrics = ['mape', 'mse'])
    return model

# %%
future_target = 3
x_train_multi, y_train_multi = multivariate_multioutput_data(dataset[:,:3], dataset[:,:3], 0,
                                                 TRAIN_SPLIT, past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_multioutput_data(dataset[:,:3], dataset[:, :3],
                                             TRAIN_SPLIT, None, past_history,
                                             future_target, STEP)

BATCH_SIZE = 128

train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
# x_train_multi.shape[1], future_target, y_train_multi.shape[2], x_train_multi.shape[2]
x_train_multi.shape[1], future_target, y_train_multi.shape[2], x_train_multi.shape[2]
# Out:
# (4, 3, 3, 3)

# %%
import time
EPOCHS = 40
steps_per_epoch = 290
validation_steps = 135

modelstart = time.time()
early_stopping = EarlyStopping(monitor='val_loss', patience = PATIENCE, restore_best_weights=True)
model = build_model(x_train_multi.shape[1], future_target, y_train_multi.shape[2], x_train_multi.shape[2])
print(model.summary())
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_norm_0 (BatchNormaliza (None, 4, 3, 1, 1)        4
# _________________________________________________________________
# conv_lstm_1 (ConvLSTM2D)     (None, 4, 3, 1, 64)       166656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 3, 1, 64)       0
# _________________________________________________________________
# batch_norm_1 (BatchNormaliza (None, 4, 3, 1, 64)       256
# _________________________________________________________________
# conv_lstm_2 (ConvLSTM2D)     (None, 3, 1, 64)          164096
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 3, 1, 64)          0
# _________________________________________________________________
# batch_norm_2 (BatchNormaliza (None, 3, 1, 64)          256
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 192)               0
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 3, 192)            0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 3, 3, 1, 64)       0
# _________________________________________________________________
# conv_lstm_3 (ConvLSTM2D)     (None, 3, 3, 1, 64)       327936
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 3, 3, 1, 64)       0
# _________________________________________________________________
# batch_norm_3 (BatchNormaliza (None, 3, 3, 1, 64)       256
# _________________________________________________________________
# conv_lstm_4 (ConvLSTM2D)     (None, 3, 3, 1, 64)       164096
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 3, 3, 1, 1)        65
# _________________________________________________________________
# dense_2 (Dense)              (None, 3, 3, 1, 1)        2
# =================================================================
# Total params: 823,623
# Trainable params: 823,237
# Non-trainable params: 386
# _________________________________________________________________
# None

# %%
# Train
print("\nTRAIN MODEL...")
history = model.fit(train_data_multi,
                    epochs = EPOCHS,
                    validation_data=val_data_multi,
                    steps_per_epoch=steps_per_epoch,
                    validation_steps=validation_steps,
                    verbose=1,
                    callbacks=[early_stopping])
model.save('multi-output-timesteps.h5')
print("\nModel Runtime: %0.2f Minutes"%((time.time() - modelstart)/60))
# Out:
# TRAIN MODEL...
# Epoch 1/40
# 290/290 [==============================] - 10s 34ms/step - loss: 103.0956 - mape: 103.0956 - mse: 1.0058 - val_loss: 100.1868 - val_mape: 100.1866 - val_mse: 1.8669
# Epoch 2/40
# 290/290 [==============================] - 9s 31ms/step - loss: 98.6314 - mape: 98.6315 - mse: 0.9500 - val_loss: 100.2188 - val_mape: 100.2189 - val_mse: 1.8775
# Epoch 3/40
# 290/290 [==============================] - 9s 31ms/step - loss: 88.1200 - mape: 88.1199 - mse: 0.7998 - val_loss: 101.1822 - val_mape: 101.1821 - val_mse: 1.4141
40
# 290/290 [==============================] - 9s 31ms/step - loss: 50.0637 - mape: 50.0637 - mse: 0.5836 - val_loss: 103.3054 - val_mape: 103.3053 - val_mse: 1.0915
# Epoch 39/40
# 290/290 [==============================] - 9s 31ms/step - loss: 49.7960 - mape: 49.7960 - mse: 0.5807 - val_loss: 104.3838 - val_mape: 104.3838 - val_mse: 1.0326
# Epoch 40/40
# 290/290 [==============================] - 9s 31ms/step - loss: 50.2289 - mape: 50.2289 - mse: 0.5828 - val_loss: 104.7664 - val_mape: 104.7665 - val_mse: 1.0632
#
# Model Runtime: 6.21 Minutes

# %%
plot_train_history(history, 'Multi-Step, Multi-Output Training and Validation loss')

# %%
np.squeeze(x[1])
# Out:
# array([[-1.58796947, -0.79752685],
#        [-0.96916902, -0.25714187],
#        [-0.73160732, -0.06757844],
#        [-0.34377429,  0.22688705]])

# %%
for x, y in val_data_multi.take(3):
    multi_step_output_plot(np.squeeze(x[0]), np.squeeze(y[0]), np.squeeze(model.predict(x[0][np.newaxis,:,:,:,:])))

# %% [markdown]
# #### Now simplifying the Convolutional LSTM

# %%
def build_model(input_timesteps, output_timesteps, num_links, num_inputs):    
    model = Sequential()
    model.add(BatchNormalization(name = 'batch_norm_0', input_shape = (input_timesteps, num_inputs, 1, 1)))
    model.add(ConvLSTM2D(name ='conv_lstm_1',
                         filters = 64, kernel_size = (10, 1),                       
                         padding = 'same', 
                         return_sequences = False))
    
    model.add(Dropout(0.1, name = 'dropout_1'))
    model.add(BatchNormalization(name = 'batch_norm_1'))

#     model.add(ConvLSTM2D(name ='conv_lstm_2',
#                          filters = 64, kernel_size = (5, 1), 
#                          padding='same',
#                          return_sequences = False))
    
#     model.add(Dropout(0.20, name = 'dropout_2'))
#     model.add(BatchNormalization(name = 'batch_norm_2'))
    
    model.add(Flatten())
    model.add(RepeatVector(output_timesteps))
    model.add(Reshape((output_timesteps, num_inputs, 1, 64)))
    
#     model.add(ConvLSTM2D(name ='conv_lstm_3',
#                          filters = 64, kernel_size = (10, 1), 
#                          padding='same',
#                          return_sequences = True))
    
#     model.add(Dropout(0.20, name = 'dropout_3'))
#     model.add(BatchNormalization(name = 'batch_norm_3'))
    
    model.add(ConvLSTM2D(name ='conv_lstm_4',
                         filters = 64, kernel_size = (5, 1), 
                         padding='same',
                         return_sequences = True))
    
    model.add(TimeDistributed(Dense(units=1, name = 'dense_1', activation = 'relu')))
    model.add(Dense(units=1, name = 'dense_2'))

#     optimizer = RMSprop() #lr=0.0001, rho=0.9, epsilon=1e-08, decay=0.9)
#     optimizer = tf.keras.optimizers.Adam(0.1)
    optimizer = tf.keras.optimizers.RMSprop(lr=0.003, clipvalue=1.0)
    model.compile(loss = "mape", optimizer = optimizer, metrics = ['mape', 'mae', 'mse'])
    return model

# %%
# Extend Prediction Window..
future_target = 6
x_train_multi, y_train_multi = multivariate_multioutput_data(dataset[:,:3], dataset[:,:3], 0,
                                                 TRAIN_SPLIT, past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_multioutput_data(dataset[:,:3], dataset[:, :3],
                                             TRAIN_SPLIT, None, past_history,
                                             future_target, STEP)

BATCH_SIZE = 128

train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
x_train_multi.shape[1], future_target, y_train_multi.shape[2], x_train_multi.shape[2]
# Out:
# (10, 6, 2, 2)

# %%
EPOCHS = 30
steps_per_epoch = 290
validation_steps = 290

modelstart = time.time()
early_stopping = EarlyStopping(monitor='val_loss', patience = PATIENCE, restore_best_weights=True)
model = build_model(x_train_multi.shape[1], future_target, y_train_multi.shape[2], x_train_multi.shape[2])
print(model.summary())

# Train
print("\nTRAIN MODEL...")
history = model.fit(train_data_multi,
                    epochs = EPOCHS,
                    validation_data=val_data_multi,
                    steps_per_epoch=steps_per_epoch,
                    validation_steps=validation_steps,
                    verbose=1,
                    callbacks=[early_stopping])
model.save('multi-output-timesteps.h5')
print("\nModel Runtime: %0.2f Minutes"%((time.time() - modelstart)/60))
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_norm_0 (BatchNormaliza (None, 10, 2, 1, 1)       4
# _________________________________________________________________
# conv_lstm_1 (ConvLSTM2D)     (None, 2, 1, 64)          166656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2, 1, 64)          0
# _________________________________________________________________
# batch_norm_1 (BatchNormaliza (None, 2, 1, 64)          256
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 128)               0
# _________________________________________________________________
# repeat_vector_2 (RepeatVecto (None, 6, 128)            0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 6, 2, 1, 64)       0
# _________________________________________________________________
# conv_lstm_4 (ConvLSTM2D)     (None, 6, 2, 1, 64)       164096
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 6, 2, 1, 1)        65
# _________________________________________________________________
# dense_2 (Dense)              (None, 6, 2, 1, 1)        2
# =================================================================
# Total params: 331,079
# Trainable params: 330,949
# Non-trainable params: 130
# _________________________________________________________________
# None
#
# TRAIN MODEL...
# Epoch 1/30
# 290/290 [==============================] - 9s 30ms/step - loss: 99.9254 - mape: 99.9254 - mae: 64007.5508 - mse: 4481796096.0000 - val_loss: 99.7308 - val_mape: 99.7308 - val_mae: 40653.9961 - val_mse: 1833260032.0000
# Epoch 2/30
# 290/290 [==============================] - 8s 28ms/step - loss: 99.6892 - mape: 99.6892 - mae: 63867.1992 - mse: 4464259072.0000 - val_loss: 99.2185 - val_mape: 99.2184 - val_mae: 40470.1680 - val_mse: 1818374272.0000
# Epoch 3/30
# 290/290 [==============================] - 8s 28ms/step - loss: 99.2934 - mape: 99.2934 - mae: 63593.3555 - mse: 4428581376.0000 - val_loss: 98.4472 - val_mape: 98.4475 - val_mae: 40193.7227 - val_mse: 1796120064.0000
# Epoch 4/30
# 290/290 [==============================] - 8s 29ms/step - loss: 98.7390 - mape: 98.7389 - mae: 63318.1406 - mse: 4394139136.0000 - val_loss: 97.4202 - val_mape: 97.4202 - val_mae: 39825.4961 - val_mse: 1766707712.0000
# Epoch 5/30
# 290/290 [==============================] - 8s 28ms/step - loss: 98.0254 - mape: 98.0253 - mae: 62900.9102 - mse: 4341942784.0000 - val_loss: 96.1362 - val_mape: 96.1359 - val_mae: 39365.0469 - val_mse: 1730324992.0000
# Epoch 6/30
# 290/290 [==============================] - 8s 28ms/step - loss: 97.1530 - mape: 97.1530 - mae: 62350.3672 - mse: 4272279808.0000 - val_loss: 94.5954 - val_mape: 94.5955 - val_mae: 38812.4258 - val_mse: 1687218688.0000
# Epoch 7/30
# 290/290 [==============================] - 8s 28ms/step - loss: 96.1252 - mape: 96.1252 - mae: 61799.3555 - mse: 4204420352.0000 - val_loss: 92.8003 - val_mape: 92.8003 - val_mae: 38168.6602 - val_mse: 1637788416.0000
# Epoch 8/30
# 290/290 [==============================] - 8s 28ms/step - loss: 68.2699 - mape: 68.2699 - mae: 45613.5586 - mse: 2471770880.0000 - val_loss: 47.4087 - val_mape: 47.4087 - val_mae: 21608.1309 - val_mse: 643684672.0000
# Epoch 21/30
# 290/290 [==============================] - 8s 28ms/step - loss: 65.0200 - mape: 65.0200 - mae: 43684.6680 - mse: 2299250432.0000 - val_loss: 43.5272 - val_mape: 43.5270 - val_mae: 19951.9961 - val_mse: 565488640.0000
# Epoch 22/30
# 290/290 [==============================] - 8s 28ms/step - loss: 61.6712 - mape: 61.6712 - mae: 41755.3633 - mse: 2135243520.0000 - val_loss: 40.0561 - val_mape: 40.0564 - val_mae: 18346.2598 - val_mse: 491739648.0000
# Epoch 23/30
# 290/290 [==============================] - 8s 28ms/step - loss: 58.1582 - mape: 58.1583 - mae: 39690.3320 - mse: 1967477120.0000 - val_loss: 36.9733 - val_mape: 36.9733 - val_mae: 16797.7754 - val_mse: 423491840.0000
# Epoch 24/30
# 290/290 [==============================] - 8s 28ms/step - loss: 54.5388 - mape: 54.5388 - mae: 37512.3789 - mse: 1797514368.0000 - val_loss: 34.3771 - val_mape: 34.3773 - val_mae: 15340.4004 - val_mse: 361877312.0000
# Epoch 25/30
# 290/290 [==============================] - 8s 29ms/step - loss: 50.8912 - mape: 50.8912 - mae: 35348.1523 - mse: 1638172288.0000 - val_loss: 32.4910 - val_mape: 32.4911 - val_mae: 14052.9375 - val_mse: 308221216.0000
# Epoch 26/30
# 290/290 [==============================] - 8s 28ms/step - loss: 47.1441 - mape: 47.1441 - mae: 33070.7188 - mse: 1479160192.0000 - val_loss: 31.3880 - val_mape: 31.3879 - val_mae: 12975.9482 - val_mse: 263741440.0000
# Epoch 27/30
# 290/290 [==============================] - 8s 28ms/step - loss: 43.3810 - mape: 43.3809 - mae: 30715.3438 - mse: 1322315264.0000 - val_loss: 31.1802 - val_mape: 31.1800 - val_mae: 12169.7900 - val_mse: 229933984.0000
# Epoch 28/30
# 290/290 [==============================] - 8s 28ms/step - loss: 39.7699 - mape: 39.7700 - mae: 28438.9258 - mse: 1179184384.0000 - val_loss: 31.9438 - val_mape: 31.9436 - val_mae: 11682.6670 - val_mse: 208211456.0000
# Epoch 29/30
# 290/290 [==============================] - 8s 28ms/step - loss: 36.4250 - mape: 36.4250 - mae: 26211.7656 - mse: 1043010432.0000 - val_loss: 33.4946 - val_mape: 33.4945 - val_mae: 11484.0586 - val_mse: 199911248.0000
# Epoch 30/30
# 290/290 [==============================] - 8s 28ms/step - loss: 33.5291 - mape: 33.5291 - mae: 24152.8320 - mse: 919754240.0000 - val_loss: 35.8589 - val_mape: 35.8591 - val_mae: 11664.6172 - val_mse: 204625168.0000
#
# Model Runtime: 4.20 Minutes

# %%
plot_train_history(history, 'Multi-Step, Multi-Output Training and Validation loss')

# %%
for x, y in val_data_multi.take(3):
    multi_step_output_plot(np.squeeze(x[0]), np.squeeze(y[0]), np.squeeze(model.predict(x[0][np.newaxis,:,:,:,:])))

# %% [markdown]
# ### TBDs
#
# - Fix ConvolutionalLSTM model above
# - Try data upto end September 2020 in above models
